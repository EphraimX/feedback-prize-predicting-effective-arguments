# %% [markdown]
# ## FEEDBACK PRIZE PREDICTING EFFECTIVE ARGUMENTS COMPETITION HOSTED ON [KAGGLE](https://www.kaggle.com/competitions/feedback-prize-effectiveness/data)
#
# *Dowload data using - "kaggle competitions download -c feedback-prize-effectiveness" command in your terminal*
